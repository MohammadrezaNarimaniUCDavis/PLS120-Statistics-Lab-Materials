# %% [markdown]
# # 🧪 PLS 120 R Statistical Playground
# **Explore, Experiment, and Discover with Statistics**
#
# ---
#
# ## 🚀 Welcome to Your Statistical Laboratory
#
# This interactive environment is your space to:
# - **🔬 Experiment** with statistical concepts
# - **📊 Explore** real datasets
# - **🧠 Learn** through hands-on practice
# - **💡 Discover** new insights
# - **🎯 Test** your ideas and hypotheses

# %% [markdown]
# ---
#
# ## 🎯 How to Use This Playground
#
# ### 📁 **Bring Your Data**
# 1. **Click the Upload button** in the left panel (📁 folder icon)
# 2. **Select your data file** (CSV, Excel, or other formats)
# 3. **Start exploring** with the code cells below
#
# ### 💡 **No Data? No Problem!**
# - Use built-in R datasets: `mtcars`, `iris`, `diamonds`, etc.
# - Generate synthetic data for testing
# - Try the example analyses provided
#
# ### 🔬 **Experiment Freely**
# - Modify any code to see what happens
# - Try different statistical approaches
# - Create new visualizations
# - Test your statistical intuition
#
# ---

# %% [markdown]
# ## 📦 Load Your Toolkit
#
# **All packages are pre-installed!** Load what you need:

# %%
# Essential libraries for statistical exploration
suppressPackageStartupMessages({
  library(ggplot2)    # Beautiful visualizations
  library(dplyr)      # Data manipulation magic
  library(readr)      # Fast data reading
  library(plotly)     # Interactive plots
  library(corrplot)   # Correlation visualizations
})

print("🚀 Your statistical toolkit is ready!")
print("💡 Tip: Add more libraries as needed with library(package_name)")

# %% [markdown]
# ---
#
# ## 📊 Quick Start: Explore Built-in Data
#
# **Try these examples to get started:**

# %%
# Quick exploration of the famous iris dataset
data(iris)
head(iris)
summary(iris)

# %%
# Create a quick visualization
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, color = Species)) +
  geom_point(size = 3, alpha = 0.7) +
  theme_minimal() +
  labs(title = "Iris Dataset Exploration",
       subtitle = "Sepal dimensions by species")

# %% [markdown]
# ---
#
# ## 📁 Your Data Workspace
#
# **Upload and load your own data here:**

# %%
# Load your data here
# Examples:
# data <- read.csv("your_file.csv")
# data <- read_excel("your_file.xlsx")
# data <- read.table("your_file.txt", header = TRUE)

# %%
# First look at your data
# str(data)        # Structure
# head(data)       # First few rows
# summary(data)    # Summary statistics
# dim(data)        # Dimensions

# %% [markdown]
# ---
#
# ## 🔍 Exploratory Data Analysis
#
# **Discover patterns and insights in your data:**

# %%
# Data exploration playground
# Try different approaches:
# - Check for missing values: sum(is.na(data))
# - Look at distributions: hist(data$column_name)
# - Check correlations: cor(data[numeric_columns])

# %%
# Visualization experiments
# Try different plot types:
# - Scatter plots: ggplot(data, aes(x, y)) + geom_point()
# - Box plots: ggplot(data, aes(group, value)) + geom_boxplot()
# - Histograms: ggplot(data, aes(x)) + geom_histogram()

# %% [markdown]
# ---
#
# ## 📊 Statistical Analysis Sandbox
#
# **Test statistical concepts and methods:**

# %%
# Descriptive statistics experiments
# Calculate measures of central tendency and spread
# mean(), median(), sd(), var(), quantile()

# %%
# Hypothesis testing playground
# Try different tests:
# - t.test() for comparing means
# - chisq.test() for categorical associations
# - cor.test() for correlation significance

# %% [markdown]
# ---
#
# ## 🧪 Advanced Analysis Laboratory
#
# **Experiment with sophisticated statistical methods:**

# %%
# Regression analysis experiments
# Try different models:
# - Linear: lm(y ~ x, data)
# - Multiple: lm(y ~ x1 + x2 + x3, data)
# - Logistic: glm(y ~ x, family = binomial, data)

# %%
# ANOVA and experimental design
# Compare groups and treatments:
# - aov(response ~ treatment, data)
# - TukeyHSD() for multiple comparisons

# %% [markdown]
# ---
#
# ## 🎨 Visualization Studio
#
# **Create compelling and informative plots:**

# %%
# Publication-quality plots
# Experiment with ggplot2 themes and aesthetics

# %%
# Interactive visualizations
# Try plotly for interactive plots:
# p <- ggplot(data, aes(x, y)) + geom_point()
# ggplotly(p)

# %% [markdown]
# ---
#
# ## 💡 Research Ideas & Experiments
#
# **Use this space for your research questions and experiments:**

# %% [markdown]
# ### 🤔 Research Questions:
#
# **Write your research questions or hypotheses here:**

# %% [raw]
# 1. [Your research question or hypothesis]
#
# 2. [Another question you want to explore]
#
# 3. [Statistical concept you want to test]

# %%
# Experiment 1: Test your first idea

# %%
# Experiment 2: Try a different approach

# %%
# Experiment 3: Compare methods

# %% [markdown]
# ---
#
# ## 📝 Your Discoveries
#
# **Document your findings and insights:**

# %% [markdown]
# ### 🔍 Key Insights:
#
# **What did you discover?**

# %% [raw]
# 1. [Interesting pattern or relationship you found]
#
# 2. [Statistical concept that became clearer]
#
# 3. [Unexpected result or surprising finding]

# %% [markdown]
# ### 🧠 What You Learned:
#
# **Reflect on your statistical journey:**

# %% [raw]
# [Write about what you learned from your exploration - new techniques,
# statistical concepts, or insights about your data]

# %% [markdown]
# ### 🚀 Next Steps:
#
# **Where will your exploration take you next?**

# %% [raw]
# [Ideas for future analysis, questions to explore, or methods to try]

# %% [markdown]
# ---
#
# ## 💾 Save Your Discoveries
#
# ### 🚨 Remember: Binder is Temporary!
#
# **Before closing:**
# 1. **File → Save** - Save your progress
# 2. **File → Download** - Download .ipynb file
# 3. **File → Export → HTML** - Create a shareable report
#
# **To continue exploring:**
# 1. Launch Binder again
# 2. Upload your saved .ipynb file
# 3. Pick up where you left off
#
# ---
#
# ## 🛠️ Your Statistical Toolkit
#
# **All these packages are ready to use:**
#
# ### 📊 **Data & Visualization:**
# `ggplot2`, `plotly`, `dplyr`, `tidyr`, `corrplot`, `pheatmap`
#
# ### 🧪 **Statistical Analysis:**
# `car`, `agricolae`, `multcomp`, `emmeans`, `broom`, `MASS`
#
# ### 🔬 **Testing & Modeling:**
# `lmtest`, `nortest`, `lawstat`, `stats`
#
# ### 📁 **Data Import:**
# `readr`, `readxl`, `data.table`
#
# **Need more?** Use `install.packages("package_name")` in any code cell!
#
# ---
#
# ## 📧 Questions or Ideas?
#
# **Mohammadreza Narimani** (Teaching Assistant)
# 📧 mnarimani@ucdavis.edu
# 🏫 Department of Biological and Agricultural Engineering, UC Davis
#
# ---
#
# ## 🎉 Happy Exploring!
#
# **Remember:** The best way to learn statistics is by doing. Don't be afraid to experiment, make mistakes, and try new approaches. Every error is a learning opportunity!
#
# **🧪 Experiment • 📊 Discover • 🚀 Learn • 🎯 Grow**
#
# ---
#
# *PLS 120 - Applied Statistics in Agricultural Sciences | UC Davis | R Statistical Playground*
