# %% [markdown]
# # 📋 PLS 120 Assignment 8
# **Applied Statistics in Agriculture**
#
# **Binder Developer:** Mohammadreza Narimani
# **Assignment Developer:** Parastoo Farajpoor
# **Date:** November 19, 2025
#
# ---

# %% [markdown]
# ## 👤 Student Information
# **Please fill in your information below:**

# %% [raw]
# Name: [YOUR NAME]
# Student ID: [STUDENT ID NUMBER]
# Date: [Today's DATE]

# %% [markdown]
# ## 📝 Assignment Overview
#
# In this assignment you will further dive into t.test in R. You will form different hypothesis and use a dataset (before_after.xlsx) to assess how biodiversity has changed due to a wildfire by comparing pre- and post-wildfire biodiversity indices for 30 forest plots.
#
# **Total Points: 20**

# %%
#load necessary packages
suppressPackageStartupMessages({
  library(ggplot2)
  library(dplyr)
})

# %% [markdown]
# ---
#
# ## PART 1: Data Import and Visualization (5 points)
#
# A) Import the data and check if it has normal distribution (2 points)
# B) Visualize the data using boxplot and briefly interpret the distribution and boxplot (3 points)

# %%
#load the dataset as csv!!
# Hint: You need to use read.csv() function to load the data and assign it to a variable called wildfire

# %%
#check the structure of the data and change class if needed 
# Hint: You need to use str() function to check the structure of your wildfire dataset

# %%
#use histogram to check the distribution
# Hint: You need to use hist() function for both wildfire$Before and wildfire$After columns

# %%
#boxplot
# Hint: You need to use ggplot() with geom_boxplot() for both Before and After columns.
# Use factor("Before") and factor("After") for x-axis, set different fill colors like skyblue and tomato.
# Add appropriate title and axis labels using labs(), and use theme_minimal() for clean appearance.
# Sample code structure:
# ggplot() +
#   geom_boxplot(aes(x = factor("___"), y = wildfire$___), fill = "___") +
#   geom_boxplot(aes(x = factor("___"), y = wildfire$___), fill = "___") +
#   labs(title = "___", x = "___", y = "___") +
#   theme_minimal()

# %% [markdown]
# ---
#
# ## PART 2: Hypothesis Testing (12 points)
#
# Form proper hypothesis for each question and use correct t.test to answer it.
#
# **Forming hypothesis for each question receives 1 point and performing t.test and answering each question receives 2 points.**

# %% [markdown]
# ### A) Has the recent wildfire significantly affected the biodiversity of the forest? (4 points)
#
# ❓ **Form your hypotheses and perform the appropriate t-test.**

# %% [raw]
# Null Hypothesis (H₀):
#
# Alternative Hypothesis (H₁):

# %%
#perform proper t.test to answer this question
# Hint: You need to use t.test() function with wildfire$Before and wildfire$After as inputs.
# Set paired = TRUE since this is a paired t-test. This is a two-tailed test by default.
# Use cat() to add a descriptive message and print() to display results.

# %% [markdown]
# ### B) Has the recent wildfire significantly increased the biodiversity of the forest? (4 points)
#
# ❓ **Form your hypotheses and perform the appropriate one-tailed t-test.**

# %% [raw]
# Null Hypothesis (H₀):
#
# Alternative Hypothesis (H₁):

# %%
#perform proper t.test to answer this question
# Hint: You need to use t.test() function with wildfire$Before and wildfire$After as inputs.
# Set paired = TRUE since this is a paired t-test and alternative = "less" to test if Before < After (meaning increase).
# Use cat() to add a descriptive message and print() to display results.

# %% [markdown]
# ### C) Has the recent wildfire significantly reduced the biodiversity of the forest? (4 points)
#
# ❓ **Form your hypotheses and perform the appropriate one-tailed t-test.**

# %% [raw]
# Null Hypothesis (H₀):
#
# Alternative Hypothesis (H₁):

# %%
#perform proper t.test to answer this question
# Hint: You need to use t.test() function with wildfire$Before and wildfire$After as inputs.
# Set paired = TRUE since this is a paired t-test and alternative = "greater" to test if Before > After (meaning decrease).
# Use cat() to add a descriptive message and print() to display results.

# %% [markdown]
# ---
#
# ## PART 3: Analysis Limitations (3 points)
#
# ### What do you think the limitations of your analysis are?
#
# ❓ **Consider factors like sample size, data quality, time window, and statistical assumptions.**

# %% [raw]
# Your answer here:
# (Hint: Think about sample size, data quality, time window of data collection, relying on one parameter (mean), assumptions of normality, etc.)

# %% [markdown]
# ---
#
# ## 📤 Submission Instructions
#
# ### How to Submit Your Assignment:
#
# 1. **Complete all code cells** and answer all questions in the raw text cells above
#
# 2. **Save your work:**
#    - Go to **File** → **Save** to save your progress
#
# 3. **Download your completed notebook:**
#    - Go to **File** → **Save and Export Notebook As** → **HTML**
#    - Also go to **File** → **Download** to get the **.ipynb** file
#
# 4. **Submit to UC Davis Canvas:**
#    - Upload both the **.html** file and **.ipynb** file
#    - Make sure your name is in the student information section at the top
#
# ### 📧 Questions or Need Help?
#
# If you have questions about this assignment or need help with R programming, please contact:
#
# **Mohammadreza Narimani**
# 📧 mnarimani@ucdavis.edu
# 🏫 Department of Biological and Agricultural Engineering, UC Davis
#
# ---
#
# **Good luck with your assignment!** 🍀
