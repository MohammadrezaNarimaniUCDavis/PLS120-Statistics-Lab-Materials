# %% [markdown]
# # 📋 PLS 120 Assignment 7
# **Applied Statistics in Agriculture**
#
# **Binder Developer:** Mohammadreza Narimani
# **Assignment Developer:** Parastoo Farajpoor
# **Date:** November 12, 2024
#
# ---

# %% [markdown]
# ## 👤 Student Information
# **Please fill in your information below:**

# %% [raw]
# Name: [YOUR NAME]
# Student ID: [STUDENT ID NUMBER]
# Date: [Today's DATE]

# %% [markdown]
# ## 📝 Assignment Overview
#
# For this assignment, we want to use the wheat.csv file that we used for assignment 6. You have a dataset containing the yields of wheat samples treated with two different types of fertilizer: a control (no fertilizer) and a nitrogen-enriched (N) fertilizer. The goal is to determine whether there is a statistically significant difference in the yields produced by these two treatments.
#
# **Total Points: 20**

# %%
#load necessary packages
suppressPackageStartupMessages({
  library(ggplot2)
  library(dplyr)
})

# %% [markdown]
# ---
#
# ## Part 1: Load and Visualize the Data (4 points)
#
# Load the dataset, and if not already done, change the fertilizer treatment to a factor. Then, use boxplot to visualize the yield under different fertilizers.

# %%
#load the data
# Hint: Define wheat variable and use read.csv() to read "wheat_yield.csv"

# %%
#change the fertilizer treatment to a factor
# Hint: Use wheat$Fertilizer and assign as.factor() to convert Fertilizer column to factor

# %%
#boxplot
# Hint: Use ggplot() with wheat data, set x=Fertilizer, y=Yield..kg.ha., fill=Fertilizer, then add geom_boxplot()

# %% [markdown]
# ---
#
# ## Part 2: Form Hypotheses (3 points)
#
# ### Question 1: What are the null and alternative hypotheses for comparing the yields from the two fertilizer treatments?
#
# ❓ **Please state both hypotheses clearly.**

# %% [raw]
# Null Hypothesis (H₀):
#
# Alternative Hypothesis (H₁):

# %% [markdown]
# ---
#
# ## Part 3: Perform T-Test and Interpret the Results (5 points)
#
# Separate the dataset by treatment. Then, use a two-sample t-test to compare the yields (assume variances are not equal).

# %%
#separate the dataset by the treatments
# Hint: Create control variable using wheat %>% filter() where Fertilizer equals "Control"
# Hint: Create nitrogen variable using wheat %>% filter() where Fertilizer equals "N"

# %%
#perform t-test and print the result
# Hint: Create t_test_results variable using t.test() with control$Yield..kg.ha. and nitrogen$Yield..kg.ha., set alternative="two.sided" and var.equal=FALSE
# Hint: Use print() function to display t_test_results

# %% [markdown]
# ---
#
# ## Part 4: Interpret the Results (4 points)
#
# ### Question 2: How would you interpret the p-value? (1 point)
#
# ❓ **Explain what the p-value tells us about the statistical significance.**

# %% [raw]
# Your answer here:

# %% [markdown]
# ### Question 3: What can you conclude about the yields from the two types of fertilizers based on this test? (2 points)
#
# ❓ **State your conclusion about the fertilizer treatments.**

# %% [raw]
# Your answer here:

# %% [markdown]
# ### Question 4: Can we reject the null hypothesis? Why or why not? (1 point)
#
# ❓ **Provide your decision and justification.**

# %% [raw]
# Your answer here:

# %% [markdown]
# ---
#
# ## Part 5: Testing if Nitrogen Fertilizer Yields are Higher (4 points)
#
# Write a code using t-test to determine if the yield from using nitrogen-enriched fertilizer is significantly higher than the yield from using the control fertilizer.

# %%
# Perform a one-sided t-test
# Hint: Create t_test_one_sided variable using t.test() with nitrogen$Yield..kg.ha. first, then control$Yield..kg.ha., set alternative="greater" and var.equal=FALSE

# %%
# Print the results
# Hint: Use print() function to display t_test_one_sided results

# %% [markdown]
# ### Question 5: Based on the result of the t-test, is the yield from using nitrogen-enriched fertilizer significantly higher than the yield from using the control fertilizer? Why or why not? (2 points)
#
# ❓ **Interpret the one-sided test results and explain your reasoning.**

# %% [raw]
# Your answer here:

# %% [markdown]
# ---
#
# ## 📤 Submission Instructions
#
# ### How to Submit Your Assignment:
#
# 1. **Complete all code cells** and answer all questions in the raw text cells above
#
# 2. **Save your work:**
#    - Go to **File** → **Save** to save your progress
#
# 3. **Download your completed notebook:**
#    - Go to **File** → **Save and Export Notebook As** → **HTML**
#    - Also go to **File** → **Download** to get the **.ipynb** file
#
# 4. **Submit to UC Davis Canvas:**
#    - Upload both the **.html** file and **.ipynb** file
#    - Make sure your name is in the student information section at the top
#
# ### 📧 Questions or Need Help?
#
# If you have questions about this assignment or need help with R programming, please contact:
#
# **Mohammadreza Narimani**
# 📧 mnarimani@ucdavis.edu
# 🏫 Department of Biological and Agricultural Engineering, UC Davis
#
# ---
#
# **Good luck with your assignment!** 🍀
