# %% [markdown]
# # 📋 PLS 120 Assignment 6
# **Applied Statistics in Agriculture**
#
# **Binder Developer:** Mohammadreza Narimani
# **Assignment Developer:** Will Hazzard
# **Date:** November 5, 2024
#
# ---

# %% [markdown]
# ## 👤 Student Information
# **Please fill in your information below:**

# %% [raw]
# Name: [YOUR NAME]
# Student ID: [STUDENT ID NUMBER]
# Date: [Today's DATE]

# %% [markdown]
# ## 📝 Assignment Overview
#
# Agronomists at UC Davis conducted a field experiment to evaluate the impact of a specific type of nitrogen fertilizer (N) on wheat yield, measured in kilograms per hectare. In the study, wheat was grown under two different conditions: one set of plots received N fertilizer at a rate of 50 kg/ha, while the other set served as a control group with no fertilizer applied.
#
# **Total Points: 20**

# %%
#load necessary packages
suppressPackageStartupMessages({
  library(ggplot2)
  library(tidyverse)
})

# %% [markdown]
# ---
#
# ## Part 1 (9 points)
#
# Load in the data, then str() it. (1 Point)

# %%
#load the data
# Hint: Use read.csv() function and assign to variable 'wheat'
wheat <- 

# Hint: Use str() function to examine the structure
str()

#if not already done, change the fertilizer treatment to a factor
# Hint: Use as.factor() on the Fertilizer column
wheat$Fertilizer <- 

# Check the structure again and count samples per group
str(wheat)
table(wheat$Fertilizer)

# %% [markdown]
# ❓ What is the sample size for this experiment? How many samples do you have for each group? (1 Point)

# %% [raw]
# The sample Size is ___ total, with ___ samples N and ___ samples Control.

# %% [markdown]
# Calculate the overall mean and standard deviation of yield for the entire dataset (2 Points)

# %%
#calculate the mean
# Hint: Use mean() function on the Yield..kg.ha. column and assign to wheat_mean
wheat_mean <- 
wheat_mean

#calculate the standard deviation
# Hint: Use sd() function on the Yield..kg.ha. column and assign to wheat_sd
wheat_sd <- 
wheat_sd

# %% [markdown]
# Calculate the z-score for the entire dataset (1 point).

# %%
#set the alpha for a 95% confidence interval
# Hint: Set alpha to 0.05 for 95% confidence
alpha <- 

#now calculate the z score
# Hint: Use qnorm(1-(alpha/2)) and assign to z_score
z_score <- 
z_score

# %% [markdown]
# Calculate the confidence interval of the mean for the entire data set. (3 points)

# %%
#first, calculate the standard error
# Hint: Use nrow() to get sample size n, then calculate SE = sd/sqrt(n)
n <- 
wheat_se <- 
wheat_se

#next calculate the margin of error
# Hint: Multiply z_score by wheat_se and assign to wheat_moe
wheat_moe <- 
wheat_moe

#now make the upper and lower bounds of the confidence interval
# Hint: UB = mean + moe, LB = mean - moe
UBwheat <- 
LBwheat <- 

#finally, make a vector containing the upper bound, mean and lower bound to make the confidence interval.
# Hint: Use c() to combine UBwheat, wheat_mean, LBwheat
CI_overall <- 
CI_overall

# %% [markdown]
# ❓ What does this confidence interval mean? What does it tell you about the effect of the fertilizer treatment on yield? (1 Point)

# %% [raw]
# Your answer here:

# %% [markdown]
# ---
#
# ## Part 2 (11 points)
#
# Now lets look at the confidence intervals for the individual treatments. Separate the data set by treatment, calculate the means and standard deviation for each, then make two new confidence intervals.

# %%
#separate the dataset by the treatments
# Hint: Use filter() to create control and nitrogen datasets
control <- wheat %>%
  filter(Fertilizer == "Control")

nitrogen <- wheat %>%
  filter(Fertilizer == "N")

#calculate the yield means and standard deviations for both treatments
# Hint: Calculate mean and sd for each group's Yield..kg.ha. column
control_mean <- 
control_sd <- 

control_mean
control_sd

nitrogen_mean <- 
nitrogen_sd <- 

nitrogen_mean
nitrogen_sd

#calculate the standard error for each
# Hint: SE = sd/sqrt(sample_size), use nrow() to get sample size
control_se <- 
control_se

nitrogen_se <- 
nitrogen_se

#calculate the margin of error for each of the treatments
# Hint: MOE = z_score * SE for each treatment
control_moe <- 
control_moe

nitrogen_moe <- 
nitrogen_moe

#calculate the upper and lower bounds for each of the treatment confidence intervals, and store them in a vector
# Hint: UB = mean + moe, LB = mean - moe, then combine with c()
UBcontrol <- 
LBcontrol <- 
CI_control <- 
CI_control

UBnitrogen <- 
LBnitrogen <- 
CI_nitrogen <- 
CI_nitrogen

# %% [markdown]
# ❓ Is there a difference between the treatment and the control? Why or why not? Justify your answer using the results from your confidence intervals. (1 point)

# %% [raw]
# Your answer here:

# %% [markdown]
# ---
#
# ## 📤 Submission Instructions
#
# ### How to Submit Your Assignment:
#
# 1. **Complete all code cells** and answer all questions in the raw text cells above
#
# 2. **Save your work:**
#    - Go to **File** → **Save** to save your progress
#
# 3. **Download your completed notebook:**
#    - Go to **File** → **Save and Export Notebook As** → **HTML**
#    - Also go to **File** → **Download** to get the **.ipynb** file
#
# 4. **Submit to UC Davis Canvas:**
#    - Upload both the **.html** file and **.ipynb** file
#    - Make sure your name is in the student information section at the top
#
# ### 📧 Questions or Need Help?
#
# If you have questions about this assignment or need help with R programming, please contact:
#
# **Mohammadreza Narimani**
# 📧 mnarimani@ucdavis.edu
# 🏫 Department of Biological and Agricultural Engineering, UC Davis
#
# ---
#
# **Good luck with your assignment!** 🍀
