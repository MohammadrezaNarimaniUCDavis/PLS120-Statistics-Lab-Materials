# %% [markdown]
# # 🎓 PLS 120 Final Project Workspace
# **Applied Statistics in Agricultural Sciences**
#
# ---
#
# ## 👤 Student Information
# **Please fill in your information below:**

# %% [raw]
# Name: [YOUR NAME]
# Student ID: [STUDENT ID NUMBER]
# Date: [Today's DATE]

# %% [markdown]
# ---
#
# ## 📋 Project Instructions
#
# Welcome to your final project workspace! This Binder environment has all the R packages you need for comprehensive statistical analysis.
#
# ### 📁 **Step 1: Upload Your Data**
# 1. **Click the Upload button** in the left panel (📁 folder icon area)
# 2. **Select your data file** (CSV, Excel, or other formats)
# 3. **Your file will appear** in the left panel once uploaded
#
# ### 📊 **Step 2: Load Your Data**
# Use the code cells below to read your data into R. Common examples:

# %%
# For CSV files
# data <- read.csv("your_file.csv")

# %%
# For Excel files
# library(readxl)
# data <- read_excel("your_file.xlsx")

# %% [markdown]
# ### 🔬 **Step 3: Analyze Your Data**
# Use the empty code cells below to perform your statistical analysis. You have access to all packages learned in class!
#
# ---

# %% [markdown]
# ## 📦 Load Required Libraries
#
# **All packages are pre-installed!** Just load what you need:

# %%
# Load essential libraries (add more as needed)
suppressPackageStartupMessages({
  library(ggplot2)    # Data visualization
  library(dplyr)      # Data manipulation
  library(readr)      # Reading CSV files
  library(knitr)      # Report generation
})

print("✅ Libraries loaded successfully!")

# %% [markdown]
# ---
#
# ## 📁 Step 1: Load Your Data
#
# **Upload your data file using the left panel, then load it here:**

# %%
# Load your data here
# Example: data <- read.csv("your_filename.csv")

# %%
# Examine your data structure
# str(data)
# head(data)
# summary(data)

# %% [markdown]
# ---
#
# ## 🔍 Step 2: Exploratory Data Analysis
#
# **Explore your data before analysis:**

# %%
# Data exploration code here

# %%
# Create visualizations

# %% [markdown]
# ---
#
# ## 📊 Step 3: Descriptive Statistics
#
# **Calculate summary statistics:**

# %%
# Descriptive statistics code here

# %%
# Additional descriptive analysis

# %% [markdown]
# ---
#
# ## 🧪 Step 4: Statistical Tests
#
# **Perform your statistical analysis:**

# %%
# Statistical tests code here

# %%
# Additional statistical analysis

# %% [markdown]
# ---
#
# ## 📈 Step 5: Advanced Analysis
#
# **Regression, ANOVA, or other advanced methods:**

# %%
# Advanced analysis code here

# %%
# Additional advanced analysis

# %% [markdown]
# ---
#
# ## 📊 Step 6: Results Visualization
#
# **Create publication-quality plots:**

# %%
# Results visualization code here

# %%
# Additional visualizations

# %% [markdown]
# ---
#
# ## 📝 Step 7: Conclusions and Interpretation
#
# **Summarize your findings:**

# %% [markdown]
# ### Key Findings:
#
# ❓ **Write your three most important findings below:**

# %% [raw]
# 1. [Your first key finding here]
#
# 2. [Your second key finding here]
#
# 3. [Your third key finding here]

# %% [markdown]
# ### Statistical Summary:
#
# ❓ **Fill in your statistical results:**

# %% [raw]
# Sample Size: [Enter sample size]
# Main Test Used: [Enter statistical test]
# P-value: [Enter p-value]
# Confidence Interval: [Enter CI if applicable]

# %% [markdown]
# ### Practical Implications:
#
# ❓ **Explain the practical significance of your results:**

# %% [raw]
# [Write about the practical significance of your results for agricultural applications]

# %% [markdown]
# ### Limitations:
#
# ❓ **Discuss any limitations of your analysis:**

# %% [raw]
# [Discuss any limitations of your analysis or data]

# %% [markdown]
# ---
#
# ## 💾 Saving Your Work
#
# ### Before Closing Binder:
# 1. **File → Save** to save your progress
# 2. **File → Download** to save the .ipynb file
# 3. **File → Save and Export Notebook As → HTML** for submission
#
# ### 📤 Submission Requirements:
# Submit **both files** to Canvas:
# - **📄 HTML file** (your formatted report)
# - **💾 .ipynb file** (your code backup)
#
# ---
#
# ## 📚 Available Packages
#
# **All these packages are pre-installed and ready to use:**
#
# ### Data Manipulation:
# - `dplyr`, `tidyr`, `readr`, `readxl`, `data.table`
#
# ### Visualization:
# - `ggplot2`, `plotly`, `corrplot`, `pheatmap`
#
# ### Statistical Analysis:
# - `car`, `agricolae`, `multcomp`, `emmeans`, `broom`
#
# ### Testing & Modeling:
# - `lmtest`, `nortest`, `lawstat`, `MASS`
#
# ### Reports:
# - `knitr`, `rmarkdown`, `DT`
#
# **Need another package?** Use `install.packages("package_name")` in any code cell!
#
# ---
#
# ## 📧 Need Help?
#
# **Mohammadreza Narimani**
# 📧 mnarimani@ucdavis.edu
# 🏫 Department of Biological and Agricultural Engineering, UC Davis
#
# ---
#
# **Good luck with your final project! 🌾📊**
